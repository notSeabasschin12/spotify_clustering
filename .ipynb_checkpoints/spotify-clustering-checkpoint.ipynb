# %%
# !pip install k-means-constrained
# Out:
# Collecting k-means-constrained
#   Downloading k_means_constrained-0.7.3-cp310-cp310-macosx_11_0_arm64.whl (353 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.4/353.4 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.6.3 in /Users/sebastianguo/anaconda3/lib/python3.10/site-packages (from k-means-constrained) (1.10.0)
# Collecting ortools>=9.4.1874
#   Downloading ortools-9.9.3963-cp310-cp310-macosx_11_0_arm64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 27.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six in /Users/sebastianguo/anaconda3/lib/python3.10/site-packages (from k-means-constrained) (1.16.0)
# Requirement already satisfied: joblib in /Users/sebastianguo/anaconda3/lib/python3.10/site-packages (from k-means-constrained) (1.1.1)
# Requirement already satisfied: numpy>=1.23.0 in /Users/sebastianguo/anaconda3/lib/python3.10/site-packages (from k-means-constrained) (1.23.5)
# Collecting absl-py>=2.0.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 20.0 MB/s eta 0:00:00
# Collecting pandas>=2.0.0
#   Downloading pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 39.1 MB/s eta 0:00:0000:010:01
# Collecting immutabledict>=3.0.0
#   Downloading immutabledict-4.2.0-py3-none-any.whl (4.7 kB)
# Collecting protobuf>=4.25.3
#   Downloading protobuf-5.26.1-cp37-abi3-macosx_10_9_universal2.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.0/404.0 kB 29.2 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 49.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sebastianguo/anaconda3/lib/python3.10/site-packages (from pandas>=2.0.0->ortools>=9.4.1874->k-means-constrained) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sebastianguo/anaconda3/lib/python3.10/site-packages (from pandas>=2.0.0->ortools>=9.4.1874->k-means-constrained) (2022.7)
# Installing collected packages: tzdata, protobuf, immutabledict, absl-py, pandas, ortools, k-means-constrained
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# Successfully installed absl-py-2.1.0 immutabledict-4.2.0 k-means-constrained-0.7.3 ortools-9.9.3963 pandas-2.2.2 protobuf-5.26.1 tzdata-2024.1

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances
from collections import defaultdict
from k_means_constrained import KMeansConstrained
# Out:
# /Users/sebastianguo/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# bring in Spotify API access token
CLIENT_ID = "122b00a742b444de9998b65664e0f628"
CLIENT_SECRET = "cb75988b96494d3c9341aeb8449ffe47"

AUTH_URL = 'https://accounts.spotify.com/api/token'
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

auth_response_data = auth_response.json()
access_token = auth_response_data['access_token']
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
BASE_URL = 'https://api.spotify.com/v1/'

# %%
PLAYLIST_IDS = {
    "liked_songs_id": "4C1EpavI1yqCw1MKG9ImQR?si=f7bc5b601d4d405b",
    "chip_chop_id": "7eAIoDwmfqgYdzqz5adjMw?si=c70314a39c9d44df",
    "hip_hop_id": "1GZ9eDb1ujSUug585ah40Q?si=54eb182afe9f4c6c",
    "couch_id": "5uxJwCYPWdFkD3H9gnG0PQ?si=a74e8d754abe4980",
    "pop_id": "1wkpuW6KINp6W84PBO0Q1n?si=81f8489d2bb9479e",
    "sad_id": "6eSIUzw1CIMVxmGriRh2Du?si=d318b817c9474cd2",
    "kpop_id": "7btk1xR1uMl3BJsDMUO7sk?si=49ac6f82971a4ff6",
    "gym_id": "5jMWW2Rt7Zf1BNdU9U7nLT?si=46fb645eaef64af3",
    "good_vibes_id": "0lxSRAAFgUk39dBCzuZiO6?si=53ad8b8c3c57402b",
    "electronic_id": "6EE3r1shbfcO1Ktkp07d2F?si=b39b54250ef0483b",
    "indie_lovecore_id": "0VtpIhMmVqiUOaLpDAOt1X?si=4e94b5e261924550",
    "euphoric_id": "0Komy1LCzHwkSbQ5LaSUIn?si=2d6ce99be64c4045"
}

# %%
# call API to get songs from playlist IDs
songs = []
for list_id in PLAYLIST_IDS:
    song_req = requests.get(BASE_URL + 'playlists/' + PLAYLIST_IDS[list_id], headers=headers).json()
    for item in song_req['tracks']['items']:
        song_info = item['track']
        song_features_req = requests.get(BASE_URL + 'audio-features/' + song_info['id'], headers=headers).json()

        song_dict = {"name": song_info['name']}
        song_dict.update(song_features_req)
        song_dict.update({"artists": [item['name'] for item in song_info['album']['artists']]})
        genres = set()
        for item in song_info['album']['artists']:
            artist_req = requests.get(BASE_URL + 'artists/' + item['id'], headers=headers).json()
            genres.update(set(artist_req['genres']))
        song_dict.update({"artists_genres": genres})
        songs.append(song_dict)

# %%
# %store songs
# Out:
# Stored 'songs' (list)

# %%
# %store -r songs
songs = list(filter(lambda x: len(x["name"]) > 0, songs))
songs[0:1]
# Out:
# [{'name': 'dangerous',
#   'danceability': 0.755,
#   'energy': 0.835,
#   'key': 5,
#   'loudness': -4.68,
#   'mode': 0,
#   'speechiness': 0.277,
#   'acousticness': 0.0635,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.575,
#   'tempo': 151.953,
#   'type': 'audio_features',
#   'id': '6LWpNGl9oKW2dFZbleaTao',
#   'uri': 'spotify:track:6LWpNGl9oKW2dFZbleaTao',
#   'track_href': 'https://api.spotify.com/v1/tracks/6LWpNGl9oKW2dFZbleaTao',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6LWpNGl9oKW2dFZbleaTao',
#   'duration_ms': 265305,
#   'time_signature': 4,
#   'artists': ['21 Savage', 'Lil Durk', 'Metro Boomin'],
#   'artists_genres': {'atl hip hop',
#    'chicago drill',
#    'chicago rap',
#    'drill',
#    'hip hop',
#    'rap',
#    'trap'}}]

# %%
track_df = pd.DataFrame(data=songs)
track_df = track_df.drop(["type", "uri", "track_href"], axis=1)
track_df['index'] = np.arange(track_df.shape[0])
track_df.head()
# Out:
#                                                 name  danceability  energy  \
# 0                                          dangerous         0.755   0.835
# 1                        Mr. Right Now (feat. Drake)         0.647   0.667
# 2                                             Runnin         0.819   0.626
# 3                             Mood (feat. iann dior)         0.701   0.716
# 4  Midsummer Madness 20 (feat. Joji, Rich Brian, ...         0.726   0.789
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    5    -4.680     0       0.2770       0.06350          0.000000    0.1510
# 1    5    -5.563     1       0.3040       0.23100          0.000000    0.1330
# 2   10    -4.574     0       0.2020       0.00748          0.101000    0.1670
# 3    7    -3.671     0       0.0361       0.17400          0.000000    0.3240
# 4    9    -5.499     1       0.0468       0.49800          0.000001    0.0907
#
#    valence    tempo                      id  \
# 0    0.575  151.953  6LWpNGl9oKW2dFZbleaTao
# 1    0.704  172.080  4Q34FP1AT7GEl9oLgNtiWj
# 2    0.415  143.010  5SWnsxjhdcEDc7LJjq9UHk
# 3    0.732   91.007  4jPy3l0RUwlUI9T5XHBW2m
# 4    0.560   94.987  5qaDbDqAwvJZgn1I15Wk3L
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6LWp...       265305
# 1  https://api.spotify.com/v1/audio-analysis/4Q34...       193839
# 2  https://api.spotify.com/v1/audio-analysis/5SWn...       195906
# 3  https://api.spotify.com/v1/audio-analysis/4jPy...       140533
# 4  https://api.spotify.com/v1/audio-analysis/5qaD...       246947
#
#    time_signature                              artists  \
# 0               4  [21 Savage, Lil Durk, Metro Boomin]
# 1               4            [21 Savage, Metro Boomin]
# 2               4            [21 Savage, Metro Boomin]
# 3               4                           [24kGoldn]
# 4               4              [88rising, Danny Ocean]
#
#                                       artists_genres  index
# 0  {atl hip hop, hip hop, chicago drill, rap, dri...      0
# 1                        {hip hop, atl hip hop, rap}      1
# 2                        {hip hop, atl hip hop, rap}      2
# 3                                {cali rap, pop rap}      3
# 4  {pop venezolano, urbano latino, reggaeton, asi...      4

# %%
# Feature Selection Using Principal Feature Analysis 
track_df_copy = track_df.copy(deep=True)
col_to_norm = ["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "key", "tempo", "duration_ms", "time_signature"]
track_features = track_df_copy[col_to_norm]
sc = StandardScaler()
num_features = sc.fit_transform(track_features)
print(num_features[0,:])
pca = PCA(n_components=num_features.shape[1]).fit(num_features)
pca_components = pca.components_.T
pca_components.shape

# cluster different features into n clusters
kmeans = KMeans(n_clusters=5, n_init='auto', random_state=4).fit(pca_components)
clusters = kmeans.predict(pca_components)
cluster_centers = kmeans.cluster_centers_
dists = defaultdict(list)

# iterate over PCA features to find, for each centroid, the closest PCA feature
for i, c in enumerate(clusters):
    dist = euclidean_distances([pca_components[i, :]], [cluster_centers[c, :]])[0][0]
    dists[c].append((i, dist))

indices = [sorted(f, key=lambda x: x[1])[0][0] for f in dists.values()]
features = [col_to_norm[f] for f in indices]
features
# Out:
# [ 0.53353692  1.20430689  0.80278731  1.39178215 -0.59092384 -0.21616307
#  -0.25209445  0.2573004  -0.1101334   1.14827662  0.79653608  0.10334848]
# ['danceability', 'energy', 'speechiness', 'valence', 'liveness']

# %%
# track_df[features] = (track_df[features]-track_df[features].min())/ \
# (track_df[features].max()-track_df[features].min())
features = ["danceability", "energy", "speechiness", "liveness"]
features_X = sc.fit_transform(track_df[features])
X = pd.concat([track_df["name"], track_df["index"], pd.DataFrame(features_X)], axis=1)
to_rename = {i: sc.get_feature_names_out()[i] for i in range(len(sc.get_feature_names_out()))}
X = X.rename(columns=to_rename)

# %%
corr_mat = X.corr(numeric_only=True)

fig, ax = plt.subplots()
im = ax.imshow(corr_mat, aspect='auto')
plt.colorbar(im)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(corr_mat.shape[0]), labels=corr_mat.columns)
ax.set_yticks(np.arange(corr_mat.shape[1]), labels=corr_mat.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

plt.show()

# %%
N_CLUSTERS = 5
kmeansc = KMeansConstrained(
    n_clusters=N_CLUSTERS,
    size_min=50,
    size_max=200,
    random_state=0
)
kmeansc.fit_predict(X[features])
labelled_data_c = pd.concat([X, pd.DataFrame({"labels": kmeansc.labels_})], axis=1)
labelled_data_c.sort_values("labels")
# Out:
#                                                   name  index  danceability  \
# 0                                            dangerous      0      0.533537
# 355                                      6 Foot 7 Foot    355     -2.154589
# 354  F**kin' Problems (feat. Drake, 2 Chainz & Kend...    354      1.319297
# 143                                     Do Not Disturb    143     -0.410753
# 351               range brothers (with Kendrick Lamar)    351     -0.100585
# ..                                                 ...    ...           ...
# 296                                            ROXANNE    296     -0.390076
# 642                                        Love On Top    642     -0.176404
# 641                                    Everybody Talks    641     -1.423970
# 401                                               Team    401      0.085516
# 116                          Bitch, Don’t Kill My Vibe    116     -0.624425
#
#        energy  speechiness  liveness  labels
# 0    1.204307     1.391782 -0.252094       0
# 355  0.679895     1.635617  0.869417       0
# 354  0.280343     1.265349 -0.500573       0
# 143  0.317801     2.954130 -0.514004       0
# 351 -0.368929     1.373720 -0.426701       0
# ..        ...          ...       ...     ...
# 296 -0.256555     0.226794  1.823037       4
# 642  0.667409    -0.309642  2.790088       4
# 641  1.759934    -0.582376  0.835838       4
# 401 -0.400144    -0.270809  0.782113       4
# 116  0.349016    -0.258166  1.702155       4
#
# [757 rows x 7 columns]

# %%
plt.scatter(X["speechiness"], X["liveness"], c=kmeansc.labels_, s=50, cmap='viridis')

centers = kmeansc.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
song_obj = {}
for cluster_i in range(N_CLUSTERS):
    song_obj[cluster_i] = list(labelled_data_c.loc[labelled_data_c["labels"] == cluster_i]["name"])

# %%
print([len(song_obj[i]) for i in song_obj])
# Out:
# [119, 200, 200, 128, 110]

# %%
song_obj[2]
# Out:
# ['Midsummer Madness 20 (feat. Joji, Rich Brian, Higher Brothers & AUGUST 08)',
#  'Angeleyes',
#  'Break Free',
#  'Problem',
#  'The Way',
#  'Cure For Me',
#  'The Nights',
#  'What the Hell',
#  '16',
#  'Pompeii',
#  'the perfect pair',
#  'BREAK MY SOUL',
#  'Sweet Dreams',
#  "As If It's Your Last",
#  'How You Like That',
#  'Pink Venom',
#  'Just the Way You Are',
#  'Runaway Baby',
#  'Boy With Luv (feat. Halsey)',
#  'Dynamite',
#  'Filter',
#  'Cigarette Daydreams',
#  'Rollin (feat. Future & Khalid)',
#  'Slide (feat. Frank Ocean & Migos)',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  '16',
#  '20 Min',
#  'The Way Life Goes (feat. Oh Wonder)',
#  'Mr. Rager',
#  'Slide (feat. Frank Ocean & Migos)',
#  'The Spins',
#  '500lbs',
#  "CAN'T SAY",
#  'Love Me',
#  'Dark Knight Dummo (feat. Travis Scott)',
#  'No Problem (feat. Lil Wayne & 2 Chainz)',
#  'All Night (feat. Knox Fortune)',
#  'No Problem (feat. Lil Wayne & 2 Chainz)',
#  "Can't Hold Us (feat. Ray Dalton)",
#  'KOD',
#  "What's Up Danger (with Black Caviar)",
#  'All Day Long',
#  'Earth',
#  'Circles',
#  'Slide (feat. Frank Ocean & Migos)',
#  'GUMMY',
#  'Tyler Herro',
#  'Nice For What',
#  'R.I.P.',
#  'Old Thing Back (feat. Ja Rule and Ralph Tresvant)',
#  'Best Song Ever',
#  '20 Min',
#  'No Idea',
#  'Death',
#  'Heartless',
#  "Can't Hold Us (feat. Ray Dalton)",
#  'Swalla (feat. Nicki Minaj & Ty Dolla $ign)',
#  'Sky',
#  'Lost Me (feat. Lil Mosey, iann dior & Lil Skies)',
#  'V12 (feat. Lil Uzi Vert)',
#  'Just For Me (with SZA) - Space Jam: A New Legacy',
#  'Every Summertime',
#  'Kiss Me More (feat. SZA)',
#  'Everybody Wants To Rule The World',
#  'Smells Like Teen Spirit',
#  "Can't Stop",
#  'Beat It',
#  'Smooth Criminal - 2012 Remaster',
#  'P.Y.T. (Pretty Young Thing)',
#  'New Romantics',
#  'Todo De Ti',
#  'Woman',
#  'Break Free',
#  'Lake Shore Drive',
#  'Despacito',
#  'Bailando - Spanish Version',
#  "Don't Stop 'Til You Get Enough",
#  'What Makes You Beautiful',
#  'All Night',
#  'We Are Never Ever Getting Back Together',
#  'Thunderclouds',
#  'Cold Cold Cold',
#  'Pumped Up Kicks',
#  'Pompeii',
#  'Good Life',
#  'Feel Again',
#  'Love Runs Out',
#  'Best Song Ever',
#  'Some Nights',
#  'Dog Days Are Over',
#  'Shake It Out',
#  "Haven't Met You Yet",
#  'Like a Prayer',
#  'This Love',
#  'ME! (feat. Brendon Urie of Panic! At The Disco)',
#  'One Thing',
#  'Feel It Still',
#  'the last great american dynasty',
#  "Don't Go Yet",
#  'Filter',
#  'Beautiful Mistakes (feat. Megan Thee Stallion)',
#  'Since U Been Gone',
#  'Firework',
#  'Physical',
#  'good 4 u',
#  'LMLY',
#  'Adderall',
#  'Midnight City',
#  'God is a woman',
#  'In Your Eyes',
#  'Hallucinate',
#  'Cool',
#  'Levitating (feat. DaBaby)',
#  "Don't Start Now",
#  'California Gurls',
#  'Gives You Hell',
#  'The One That Got Away',
#  'Kyoto',
#  'The Feels',
#  'OMG',
#  'Super Shy',
#  'What is Love',
#  'GO HARD',
#  'Pink Venom',
#  'DDU-DU DDU-DU',
#  'Kill This Love',
#  'How You Like That',
#  'DNA',
#  'Boy With Luv (feat. Halsey)',
#  'Dynamite',
#  'Filter',
#  "As If It's Your Last",
#  'Perfect Night',
#  'New Jeans',
#  'GODS',
#  'ANTIFRAGILE',
#  'Blue Flame',
#  'UNFORGIVEN (feat. Nile Rodgers)',
#  'The Great Mermaid',
#  'Love Shot',
#  'POP!',
#  'EASY',
#  "Can't Hold Us (feat. Ray Dalton)",
#  'INDUSTRY BABY (feat. Jack Harlow)',
#  'STARGAZING',
#  'Sky',
#  'Levitating (feat. DaBaby)',
#  'Hey Ya!',
#  'Love Again',
#  'Whatever It Takes',
#  'Worst Behavior',
#  'Break Free',
#  'Black and Yellow',
#  'Unforgettable',
#  'Love Me',
#  'Nice For What',
#  'Beauty And A Beat',
#  'Congratulations',
#  'Pray For Me',
#  'Sunroof',
#  'What the Hell',
#  'Happy - From "Despicable Me 2"',
#  "I Ain't Worried",
#  'Cure For Me',
#  'Left Hand Free',
#  'Rollin (feat. Future & Khalid)',
#  'Teenage Dream',
#  'Raise Your Glass',
#  'Take My Breath - Single Version',
#  'Kiss Me Thru The Phone',
#  'STAY (with Justin Bieber)',
#  'Since U Been Gone',
#  'Midnight City',
#  'The Spins',
#  'TiK ToK',
#  'Good Life',
#  'The Way',
#  'What Makes You Beautiful',
#  'ME! (feat. Brendon Urie of Panic! At The Disco)',
#  'Die Young',
#  'Dynamite',
#  'Good In Bed',
#  'Dynamite',
#  'Get Lucky (feat. Pharrell Williams and Nile Rodgers)',
#  'Aerodynamic',
#  "Cupid's Chokehold / Breakfast in America",
#  'Notion',
#  'Kiss Me More (feat. SZA)',
#  'Sweater Weather',
#  'Tek It',
#  'Kill Bill',
#  '505',
#  'Borderline',
#  'Honeypie',
#  'Cigarette Daydreams',
#  'She Knows (feat. Amber Coffman & Cults)',
#  'Dead To Me',
#  'My Kind Of Woman',
#  'Mr. Rager',
#  'Tongue Tied']

# %%
song_clst = labelled_data_c.loc[(labelled_data_c["labels"] == 0) | (labelled_data_c["labels"] == 1)]
plt.scatter(song_clst["danceability"], song_clst["liveness"], c=song_clst["labels"], s=50, cmap='viridis')
